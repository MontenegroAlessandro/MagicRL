# %%
import sys
# sys.path.append('/Users/gianmarcotedeschi/Projects/learnRL/')

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt
import json
# from simulation.trajectory_sampler import *
# from envs import *
# from policies import *
# from data_processors import *
from scipy.stats import sem, t
import os


font = {'size'   : 14}
plt.rc('font', **font)  # pass in the font dict as kwargs

# GAPS
# font = {'size'   : 20}
# plt.rc('font', **font)  # pass in the font dict as kwargs

# %%
# Funzione per caricare i dati da un percorso
def load_trials(base_path, n_exp):
    trial_performances = []
    det_performances = []
    for i in range(n_exp):
        trial_path = os.path.join(base_path, f"_trial_{i}")
        if os.path.isdir(trial_path):
            try:
                file_path = os.path.join(trial_path, "results.json")
                with open(file_path, 'r') as file:
                    data = json.load(file)
                    trial_performances.append(data["performance"])
                    # det_performances.append(data["deterministic_res"])
            except (FileNotFoundError, json.JSONDecodeError) as e:
                print(f"Errore nel leggere {file_path}: {e}")
    return np.array(trial_performances), np.array(det_performances)  # Converte in array per calcoli successivi

# %% [markdown]
# # PGPE Finite Differences

# %%
# # Path principali per i risultati

paths = [
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_pgpe/_03_17-17_08_02_seed_0_pgpe_4250_swimmer_200_adam_01_linear_batch_100_noclip_16_var_01",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_pgpe/_03_17-18_36_47_seed_0_pgpe_4250_swimmer_200_adam_01_linear_batch_100_noclip_16_var_03",
    
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_pgpe/_03_17-17_50_23_seed_0_pgpe_fd_250_swimmer_200_adam_01_linear_batch_100_noclip_16_var_01",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_pgpe/_03_17-16_25_44_seed_0_pgpe_fd_250_swimmer_200_adam_03_linear_batch_100_noclip_16_var_01",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/results_pgpefd/_03_18-03_30_32_seed_0_pgpe_fd_250_swimmer_200_adam_05_linear_batch_100_noclip_16_var_01",


    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_pgpe/_03_18-11_23_39_seed_0_pgpe_4250_swimmer_200_adam_01_linear_batch_100_clip_16_var_03",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_pgpe/_03_18-10_23_42_seed_0_pgpe_fd_250_swimmer_200_adam_05_linear_batch_100_clip_16_var_01",
    "/Users/gianmarcotedeschi/Projects/MagicRL/test_pgpe/_03_18-18_48_29_seed_0_pgpe_fd_250_swimmer_200_adam_05_linear_batch_100_clip_16_var_01", 
    "/Users/gianmarcotedeschi/Projects/MagicRL/test_swimmer/_03_19-11_12_31_seed_0_pgpe_fd_250_swimmer_200_adam_05_linear_batch_100_noclip_16_var_01",
    
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_pgpe/_03_18-13_25_53_seed_0_pgpe_4250_hopper_100_adam_01_linear_batch_100_noclip_33_var_01",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_pgpe/_03_18-12_06_39_seed_0_pgpe_fd_250_hopper_100_adam_05_linear_batch_100_noclip_33_var_01",

    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_pgpe/_03_18-17_25_11_seed_0_pgpe_4250_half_cheetah_100_adam_01_linear_batch_100_clip_102_var_01",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_pgpe/_03_18-15_48_29_seed_0_pgpe_fd_250_half_cheetah_100_adam_01_linear_batch_100_clip_102_var_05",

    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_pgpe/_03_18-18_32_45_seed_0_pgpe_1000_lqr_50_adam_01_linear_batch_100_clip_2_var_01",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_pgpe/_03_18-18_32_01_seed_0_pgpe_fd_100_lqr_50_adam_01_linear_batch_100_clip_2_var_01"
]

# Labels per i trial
lab = [
    "PGPE",
    "PGPE-FD",

    "PGPE2",
    "PGPE-FD2",
]

# Timesteps raccolti a ogni iterazione per ciascun algoritmo
horizon = 200
batch_size = 100
n_params_pgpe_fd = 16

timesteps_per_iteration = [
    horizon * batch_size                           # PGPE
    horizon * batch_size * (1 + n_params_pgpe_fd),   # PGPE-FD: base + 1 perturbazione per parametro
]
# Out:
#   Cell In[79], line 43
#     horizon * batch_size * (1 + n_params_pgpe_fd),   # PGPE-FD: base + 1 perturbazione per parametro
#     ^
# SyntaxError: invalid syntax

# %%
# # Path principali per i risultati

paths = [
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_swimmer/_03_19-16_09_07_seed_0_pgpe_4250_swimmer_200_adam_01_linear_batch_100_noclip_16_var_03",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_swimmer/_03_20-11_36_12_seed_0_pgpe_4250_swimmer_200_adam_01_linear_batch_100_clip_16_var_03",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_swimmer/_03_20-10_33_40_seed_0_pgpe_fd_250_swimmer_200_adam_05_linear_batch_100_clip_16_var_01",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_swimmer/_03_19-17_16_03_seed_0_pgpe_fd_250_swimmer_200_adam_01_linear_batch_100_noclip_16_var_01",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_swimmer/_03_19-18_37_48_seed_0_pgpe_fd_250_swimmer_200_adam_05_linear_batch_100_noclip_16_var_01",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_swimmer/_03_19-19_53_03_seed_0_pgpe_fd_250_swimmer_200_adam_005_linear_batch_100_noclip_16_var_01",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_swimmer/_03_19-23_28_52_seed_0_pgpe_fd_250_swimmer_200_adam_01_linear_batch_100_noclip_16_var_001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_swimmer/_03_20-00_47_35_seed_0_pgpe_fd_250_swimmer_200_adam_05_linear_batch_100_noclip_16_var_001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_swimmer/_03_20-02_10_17_seed_0_pgpe_fd_250_swimmer_200_adam_005_linear_batch_100_noclip_16_var_001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_swimmer/_03_20-03_32_00_seed_0_pgpe_fd_250_swimmer_200_adam_01_linear_batch_100_noclip_16_var_0001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_swimmer/_03_20-04_43_35_seed_0_pgpe_fd_250_swimmer_200_adam_05_linear_batch_100_noclip_16_var_0001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_swimmer/_03_20-05_54_24_seed_0_pgpe_fd_250_swimmer_200_adam_005_linear_batch_100_noclip_16_var_0001",

    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_2/_03_19-11_50_30_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_05",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_2/_03_19-11_51_56_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_01",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_2/_03_19-11_53_21_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_005",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_2/_03_19-11_54_44_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_2/_03_19-11_56_10_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_0001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_2/_03_19-11_57_34_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_00005",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_2/_03_19-11_59_00_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_00001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_2/_03_19-12_00_30_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_5e-05",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_2/_03_19-12_01_40_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_1e-05",


    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_pendulum/_03_20-11_23_30_seed_0_pgpe_4250_ip_200_adam_01_linear_batch_100_noclip_4_var_03",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_pendulum/_03_20-14_28_41_seed_0_pgpe_4250_ip_200_adam_01_linear_batch_100_noclip_4_var_01",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_pendulum/_03_20-12_05_13_seed_0_pgpe_fd_250_ip_200_adam_05_linear_batch_100_noclip_4_var_01",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_pendulum/_03_20-12_25_55_seed_0_pgpe_fd_250_ip_200_adam_01_linear_batch_100_noclip_4_var_01",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_pendulum/_03_20-12_37_59_seed_0_pgpe_fd_250_ip_200_adam_001_linear_batch_100_noclip_4_var_01",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_pendulum/_03_20-12_47_23_seed_0_pgpe_fd_250_ip_200_adam_05_linear_batch_100_noclip_4_var_001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_pendulum/_03_20-12_59_07_seed_0_pgpe_fd_250_ip_200_adam_01_linear_batch_100_noclip_4_var_001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_pendulum/_03_20-13_11_03_seed_0_pgpe_fd_250_ip_200_adam_001_linear_batch_100_noclip_4_var_001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_pendulum/_03_20-13_21_08_seed_0_pgpe_fd_250_ip_200_adam_05_linear_batch_100_noclip_4_var_0001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_pendulum/_03_20-13_29_41_seed_0_pgpe_fd_250_ip_200_adam_01_linear_batch_100_noclip_4_var_0001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_pendulum/_03_20-13_39_18_seed_0_pgpe_fd_250_ip_200_adam_001_linear_batch_100_noclip_4_var_0001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_pendulum/_03_20-13_47_26_seed_0_pgpe_fd_250_ip_200_adam_05_linear_batch_100_noclip_4_var_00001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_pendulum/_03_20-13_48_17_seed_0_pgpe_fd_250_ip_200_adam_01_linear_batch_100_noclip_4_var_00001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_pendulum/_03_20-13_57_57_seed_0_pgpe_fd_250_ip_200_adam_001_linear_batch_100_noclip_4_var_00001",


    # LQ Sensitivity analysis
    # LQ 1x1
    # PGPE
    "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_2/_03_19-12_02_48_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_2_var_05",
    "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_2/_03_19-12_05_34_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_2_var_01",
    "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_2/_03_19-12_08_21_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_2_var_005",
    "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_2/_03_19-12_11_06_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_2_var_001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_2/_03_19-12_13_53_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_2_var_0001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_2/_03_19-12_16_41_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_2_var_00005",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_2/_03_19-12_19_27_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_2_var_00001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_2/_03_19-12_22_12_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_2_var_5e-05",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_2/_03_19-12_24_59_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_2_var_1e-05",
    # PGPE-FD
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_03_20_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_05_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_04_34_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_01_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_05_46_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_005_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_06_57_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_001_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_08_07_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_0001_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_09_17_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_00005_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_10_30_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_00001_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_11_41_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_5e-05_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_12_54_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_1e-05_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_14_06_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_05_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_16_25_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_01_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_18_44_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_005_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_21_00_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_001_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_23_18_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_0001_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_25_35_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_00005_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_27_57_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_00001_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_30_15_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_5e-05_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_32_36_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_1e-05_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_34_52_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_05_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_38_48_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_01_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_42_48_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_005_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_46_43_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_001_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_50_35_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_0001_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_54_31_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_00005_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_58_26_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_00001_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-19_02_19_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_5e-05_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-19_06_12_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_1e-05_fd_five_point",

    # LQ 2x2
    # PGPE
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-19_52_56_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_4_var_05",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-19_55_55_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_4_var_01",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-19_58_55_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_4_var_005",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_01_58_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_4_var_001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_04_52_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_4_var_0001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_07_38_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_4_var_00005",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_10_27_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_4_var_00001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_13_16_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_4_var_5e-05",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_16_02_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_4_var_1e-05",
    # # PGPE-FD
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_44_55_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_05_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_46_07_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_01_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_47_19_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_005_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_48_31_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_001_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_49_44_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_0001_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_50_55_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_00005_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_52_07_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_00001_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_53_20_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_5e-05_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_54_33_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_1e-05_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_55_45_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_05_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_59_41_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_01_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-22_03_39_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_005_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-22_07_34_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_001_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-22_11_31_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_0001_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-22_15_30_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_00005_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-22_19_26_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_00001_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-22_23_21_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_5e-05_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-22_27_19_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_1e-05_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-22_31_15_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_05_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-22_38_32_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_01_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-22_45_42_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_005_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-22_52_54_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_001_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-23_00_09_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_0001_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-23_07_24_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_00005_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-23_14_39_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_00001_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-23_21_51_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_5e-05_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-23_29_06_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_1e-05_fd_five_point",

    # # LQ 4x4
    # # PGPE
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_18_48_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_16_var_05",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_21_36_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_16_var_01",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_24_24_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_16_var_005",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_27_14_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_16_var_001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_30_03_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_16_var_0001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_32_52_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_16_var_00005",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_35_40_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_16_var_00001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_38_28_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_16_var_5e-05",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_41_18_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_16_var_1e-05",
    # # PGPE-FD
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-23_36_22_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_05_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-23_38_34_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_01_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-23_40_43_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_005_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-23_42_52_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_001_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-23_45_01_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_0001_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-23_47_11_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_00005_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-23_49_22_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_00001_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-23_51_31_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_5e-05_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-00_09_55_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_01_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-00_23_51_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_005_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-00_37_51_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_001_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-00_51_49_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_0001_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-01_05_45_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_00005_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-01_19_40_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_00001_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-01_33_44_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_5e-05_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-01_47_41_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_1e-05_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-02_01_36_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_05_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-02_28_50_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_01_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-02_56_33_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_005_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-03_23_49_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_001_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-03_51_24_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_0001_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-04_18_45_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_00005_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-04_46_06_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_00001_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-05_13_21_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_5e-05_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-05_40_43_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_1e-05_fd_five_point",

    # #LQ 8x8
    # # PGPE
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_44_06_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_64_var_05",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_47_09_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_64_var_01",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_50_15_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_64_var_005",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_53_16_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_64_var_001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_56_18_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_64_var_0001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_59_20_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_64_var_00005",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_02_24_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_64_var_00001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_05_26_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_64_var_5e-05",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_08_28_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_64_var_1e-05",
    # # PGPE-FD
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-06_07_57_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_05_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-06_14_00_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_01_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-06_20_03_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_005_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-06_26_04_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_001_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-06_32_06_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_0001_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-06_38_06_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_00005_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-06_44_05_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_00001_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-06_50_04_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_5e-05_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-06_56_08_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_1e-05_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-07_02_09_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_05_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-07_56_51_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_01_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-08_52_35_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_005_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-09_47_59_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_001_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-10_42_51_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_0001_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-11_38_03_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_00005_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-12_32_31_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_00001_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-13_48_51_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_5e-05_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-14_43_05_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_1e-05_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-15_37_33_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_05_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_23-10_59_12_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_01_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_23-12_50_33_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_005_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_23-14_42_15_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_001_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_23-16_34_58_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_0001_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_23-18_26_33_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_00005_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_23-20_19_31_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_00001_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_23-22_44_55_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_5e-05_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_24-00_34_12_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_1e-05_fd_five_point",

    # LQ 16x16
    # PGPE
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_11_32_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_256_var_05",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_15_15_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_256_var_01",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_18_57_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_256_var_005",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_22_39_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_256_var_001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_26_22_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_256_var_0001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_30_04_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_256_var_00005",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_33_46_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_256_var_00001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_37_29_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_256_var_5e-05",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_41_13_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_256_var_1e-05",

]

# Labels estratte automaticamente (solo lr e var)
def build_label_from_path(path):
    exp_name = os.path.basename(path.rstrip("/")).lstrip("_")
    tokens = exp_name.split("_")

    lr_value = "NA"
    var_value = "NA"
    algo = "NA"

    for i, token in enumerate(tokens[:]):
        if token == "pgpe":
            algo = "PGPE"
        elif token == "fd":
            algo = "PGPE-FD"
        
        if token in ("adam", "constant"):
            lr_type = tokens[i]
            lr_value = tokens[i + 1]
        elif token == "var":
            var_value = tokens[i + 1]

        if token == "forward":
            algo += " og"
        elif token == "central":
            algo += " a"
        elif token == "five":
            algo += " b"

    # return f"{lr_type}={lr_value} | std={var_value}"
    return f"{algo} | std={var_value}"

lab = [build_label_from_path(path) for path in paths]

# Timesteps raccolti a ogni iterazione per ciascun algoritmo
horizon = 50
batch_size = 100
n_params_pgpe_fd = 1

# timesteps_per_iteration = {
#     "PGPE": horizon * batch_size,
#     "PGPE-FD og": horizon * batch_size * (1 + n_params_pgpe_fd) * 2,   # base + 1 perturbazione per parametro, moltiplicato per 2 per central difference
#     "PGPE-FD a": horizon * batch_size * (1 + n_params_pgpe_fd) * 2,   # base + 1 perturbazione per parametro, moltiplicato per 2 per central difference
#     "PGPE-FD b": horizon * batch_size * (1 + n_params_pgpe_fd) * 4,   # base + 1 perturbazione per parametro, moltiplicato per 2 per central difference

# }

# timesteps_per_iteration = horizon * batch_size * (1 + n_params_pgpe_fd) * 2 # PGPE-FD: base + 1 perturbazione per parametro
# timesteps_per_iteration = [
#     horizon * batch_size * (1 + n_params_pgpe_fd),   # PGPE-FD: base + 1 perturbazione per parametro
#     horizon * batch_size * (1 + n_params_pgpe_fd) * 2
# ]

print(lab)
# Out:
# ['PGPE | std=05', 'PGPE | std=01', 'PGPE | std=005', 'PGPE | std=001']

# %%
# # Path principali per i risultati

paths = [
    # LQR 2x2 [2, 32, 32, 2]
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_latest/_03_27-18_19_21_seed_0_pgpe_500_lqr_50_adam_001_nn_batch_100_noclip_1152_var_005",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_latest/_03_27-18_30_25_seed_0_pgpe_500_lqr_50_adam_001_linear_batch_100_noclip_4_var_005",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_latest_pgpe-fd/_03_30-19_38_02_seed_0_pgpe_fd_150_lqr_50_adam_001_nn_batch_100_noclip_1152_var_01_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_latest_pgpe-fd/_03_31-00_36_16_seed_0_pgpe_fd_150_lqr_50_adam_001_nn_batch_100_noclip_1152_var_005_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_latest_pgpe-fd/_03_31-04_37_16_seed_0_pgpe_fd_150_lqr_50_adam_001_nn_batch_100_noclip_1152_var_001_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_latest_pgpe-fd/_03_31-08_37_42_seed_0_pgpe_fd_150_lqr_50_adam_001_nn_batch_100_noclip_1152_var_0001_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_latest_pgpe-fd/_03_31-13_05_51_seed_0_pgpe_fd_150_lqr_50_adam_001_nn_batch_100_noclip_1152_var_00001_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_latest_pgpe-fd/_03_31-17_36_36_seed_0_pgpe_fd_150_lqr_50_adam_001_nn_batch_100_noclip_1152_var_1e-05_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_44_55_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_05_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_46_07_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_01_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_47_19_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_005_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_48_31_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_001_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_49_44_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_0001_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_50_55_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_00005_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_52_07_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_00001_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_53_20_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_5e-05_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_54_33_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_1e-05_fd_forward",
    
    # LQR 4x4 [4, 32, 32, 4]
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_latest/_03_27-18_36_58_seed_0_pgpe_500_lqr_50_adam_001_nn_batch_100_noclip_1280_var_005",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_latest/_03_27-18_48_03_seed_0_pgpe_500_lqr_50_adam_001_linear_batch_100_noclip_16_var_005",

    # LQR 8x8 [8, 32, 32, 8]
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_latest/_03_27-18_55_04_seed_0_pgpe_500_lqr_50_adam_001_nn_batch_100_noclip_1536_var_005",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_latest/_03_27-19_08_36_seed_0_pgpe_500_lqr_50_adam_001_linear_batch_100_noclip_64_var_001",
]

# Labels estratte automaticamente (solo lr e var)
def build_label_from_path(path):
    exp_name = os.path.basename(path.rstrip("/")).lstrip("_")
    tokens = exp_name.split("_")

    lr_value = "NA"
    var_value = "NA"
    algo = "NA"

    for i, token in enumerate(tokens[:]):
        if token == "pgpe":
            algo = "PGPE"
        elif token == "fd":
            algo = "PGPE-FD"
        
        if token in ("adam", "constant"):
            lr_type = tokens[i]
            lr_value = tokens[i + 1]
        elif token == "var":
            var_value = tokens[i + 1]

        if token == "forward":
            algo += " og"
        elif token == "central":
            algo += " a"
        elif token == "five":
            algo += " b"

    # return f"{lr_type}={lr_value} | std={var_value}"
    return f"{algo} | std={var_value}"

lab = [build_label_from_path(path) for path in paths]

# Timesteps raccolti a ogni iterazione per ciascun algoritmo
horizon = 50
batch_size = 100
n_params_pgpe_fd = 1

# timesteps_per_iteration = {
#     "PGPE": horizon * batch_size,
#     "PGPE-FD og": horizon * batch_size * (1 + n_params_pgpe_fd) * 2,   # base + 1 perturbazione per parametro, moltiplicato per 2 per central difference
#     "PGPE-FD a": horizon * batch_size * (1 + n_params_pgpe_fd) * 2,   # base + 1 perturbazione per parametro, moltiplicato per 2 per central difference
#     "PGPE-FD b": horizon * batch_size * (1 + n_params_pgpe_fd) * 4,   # base + 1 perturbazione per parametro, moltiplicato per 2 per central difference

# }

# timesteps_per_iteration = horizon * batch_size * (1 + n_params_pgpe_fd) * 2 # PGPE-FD: base + 1 perturbazione per parametro
# timesteps_per_iteration = [
#     horizon * batch_size * (1 + n_params_pgpe_fd),   # PGPE-FD: base + 1 perturbazione per parametro
#     horizon * batch_size * (1 + n_params_pgpe_fd) * 2
# ]

print(lab)
# Out:
# ['NA | std=01', 'NA | std=005', 'NA | std=001']

# %%
# Lista per memorizzare le performance per ogni set
all_performances = []
all_det_performances = []

for path in paths:
    performances, det_performances = load_trials(path, n_exp=3)
    if performances.size > 0:
        all_performances.append(performances)
    if det_performances.size > 0:
        all_det_performances.append(det_performances)

# %%
print(len(all_performances[0]))
# Out:
# 3

# %%
# Plot dei grafici
plt.clf()
# plt.figure(figsize=(6.5, 4.5))
plt.figure(figsize=(10, 6))

for i, performances in enumerate(all_performances):
    if performances.size > 0:
         # Calcola la media e gli intervalli di confidenza
        mean_performance = np.mean(performances, axis=0)
        std_performance = np.std(performances, axis=0)

        # Asse x in timesteps cumulati
        # x = (np.arange(len(mean_performance)) + 1) * timesteps_per_iteration[i]
        
        x = (np.arange(len(mean_performance)))
        # Plot della curva media
        plt.plot(x, mean_performance, linewidth=2, label=lab[i])

        # Plot dell'intervallo di confidenza
        lower = mean_performance-(std_performance)*1.96/np.sqrt(performances.shape[0])
        higher = mean_performance+(std_performance)*1.96/np.sqrt(performances.shape[0])

        plt.fill_between(
            x,
            lower,
            higher,
            alpha=0.2
        )

        # print(np.mean(mean_performance))
        # print(np.mean(lower))
        # print(np.mean(higher))

# Etichette e titolo
# plt.title("Dam")
# plt.xlabel("Iterations")
plt.xlabel("Total timesteps")
plt.ylabel("Return")
# plt.xlim(0, 250)

plt.legend(loc="lower right", ncol=2)
plt.grid()
# plt.ylim(bottom=-400, top=-90)
# plt.xlim(right=2*1e7)
# Salva e mostra il grafico
# plt.savefig("swimmer_persistence.pdf", format='pdf', bbox_inches='tight')
plt.show()

# %%
# Plot dei grafici
plt.clf()
# plt.figure(figsize=(6.5, 4.5))
plt.figure(figsize=(10, 6))

def get_timesteps_per_iteration_for_path(path):
    if "_pgpe_fd_" in path:
        if "_fd_five_point" in path:
            fd_multiplier = 4
        elif "_fd_central" in path:
            fd_multiplier = 2
        else:
            fd_multiplier = 1
        return horizon * batch_size * (1 + n_params_pgpe_fd) * fd_multiplier
    return horizon * batch_size

for i, performances in enumerate(all_performances):
    if performances.size > 0:
        # Calcola la media e gli intervalli di confidenza
        mean_performance = np.mean(performances, axis=0)
        std_performance = np.std(performances, axis=0)
        
        print("last performance value:", mean_performance[-1])

        # Asse x in timesteps cumulati
        ts_per_iteration = get_timesteps_per_iteration_for_path(paths[i])
        x = (np.arange(len(mean_performance))) * ts_per_iteration

        plt.plot(x, mean_performance, linewidth=2, label=lab[i])

        # Plot dell'intervallo di confidenza
        lower = mean_performance-(std_performance)*1.96/np.sqrt(performances.shape[0])
        higher = mean_performance+(std_performance)*1.96/np.sqrt(performances.shape[0])

        plt.fill_between(
            x,
            lower,
            higher,
            alpha=0.2
        )

        # print(np.mean(mean_performance))
        # print(np.mean(lower))
        # print(np.mean(higher))

# for i, performances in enumerate(all_det_performances):
#     if performances.size > 0:
#          # Calcola la media e gli intervalli di confidenza
#         mean_performance = np.mean(performances, axis=0)
#         std_performance = np.std(performances, axis=0)

#         # Asse x in timesteps cumulati
#         ts_per_iteration = get_timesteps_per_iteration_for_path(paths[i])
#         x = (np.arange(len(mean_performance)) + 1) * ts_per_iteration
        
#         # x = (np.arange(len(mean_performance)))
#         # Plot della curva media
#         plt.plot(x, mean_performance, linewidth=2, label=lab[i] + " (det)")

#         # Plot dell'intervallo di confidenza
#         lower = mean_performance-(std_performance)*1.96/np.sqrt(performances.shape[0])
#         higher = mean_performance+(std_performance)*1.96/np.sqrt(performances.shape[0])

#         plt.fill_between(
#             x,
#             lower,
#             higher,
#             alpha=0.2
#         )

#         # print(np.mean(mean_performance))
#         # print(np.mean(lower))
#         # print(np.mean(higher))

# Etichette e titolo
# plt.title("Dam")
# plt.xlabel("Iterations")
plt.xlabel("Total timesteps")
plt.ylabel("Return")
plt.ylim(bottom=-3000, top=-90)
# plt.xlim(0, 2000000)

plt.legend(loc="lower right", ncol=2)
plt.grid()
# plt.ylim(bottom=-400, top=-90)
# plt.xlim(right=0.25*1e7)
# Salva e mostra il grafico
# plt.savefig("swimmer_persistence.pdf", format='pdf', bbox_inches='tight')
plt.show()
# Out:
# last performance value: -710.8403925777994
# last performance value: -440.05078411268477
# last performance value: -839.1526471941335
# last performance value: -1079.9248313281998
# last performance value: -5197.317877814062
# last performance value: -6304.004420590921
# last performance value: -171.06584226119125
# last performance value: -131.90250990395398
# last performance value: -128.58121243004342
# last performance value: -127.3267496149886
# last performance value: -127.23169657573881
# last performance value: -127.22791038472724
# last performance value: -127.2249860399207
# last performance value: -127.2246269828297
# last performance value: -127.22434077061332

# %%
# # Path principali per i risultati

paths = [
    # LQ Sensitivity analysis
    # LQ 1x1
    # PGPE
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_2/_03_19-12_02_48_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_2_var_05",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_2/_03_19-12_05_34_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_2_var_01",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_2/_03_19-12_08_21_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_2_var_005",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_2/_03_19-12_11_06_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_2_var_001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_2/_03_19-12_13_53_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_2_var_0001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_2/_03_19-12_16_41_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_2_var_00005",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_2/_03_19-12_19_27_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_2_var_00001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_2/_03_19-12_22_12_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_2_var_5e-05",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_2/_03_19-12_24_59_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_2_var_1e-05",
    # PGPE-FD
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_03_20_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_05_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_04_34_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_01_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_05_46_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_005_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_06_57_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_001_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_08_07_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_0001_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_09_17_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_00005_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_10_30_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_00001_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_11_41_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_5e-05_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_12_54_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_1e-05_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_14_06_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_05_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_16_25_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_01_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_18_44_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_005_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_21_00_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_001_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_23_18_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_0001_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_25_35_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_00005_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_27_57_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_00001_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_30_15_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_5e-05_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_32_36_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_1e-05_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_34_52_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_05_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_38_48_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_01_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_42_48_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_005_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_46_43_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_001_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_50_35_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_0001_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_54_31_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_00005_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-18_58_26_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_00001_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-19_02_19_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_5e-05_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_3/_03_21-19_06_12_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_2_var_1e-05_fd_five_point",

    # LQ 2x2
    # PGPE
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-19_52_56_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_4_var_05",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-19_55_55_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_4_var_01",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-19_58_55_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_4_var_005",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_01_58_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_4_var_001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_04_52_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_4_var_0001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_07_38_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_4_var_00005",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_10_27_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_4_var_00001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_13_16_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_4_var_5e-05",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_16_02_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_4_var_1e-05",
    # # PGPE-FD
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_44_55_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_05_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_46_07_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_01_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_47_19_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_005_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_48_31_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_001_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_49_44_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_0001_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_50_55_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_00005_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_52_07_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_00001_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_53_20_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_5e-05_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_54_33_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_1e-05_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_55_45_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_05_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_59_41_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_01_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-22_03_39_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_005_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-22_07_34_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_001_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-22_11_31_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_0001_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-22_15_30_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_00005_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-22_19_26_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_00001_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-22_23_21_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_5e-05_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-22_27_19_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_1e-05_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-22_31_15_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_05_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-22_38_32_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_01_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-22_45_42_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_005_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-22_52_54_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_001_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-23_00_09_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_0001_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-23_07_24_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_00005_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-23_14_39_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_00001_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-23_21_51_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_5e-05_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-23_29_06_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_4_var_1e-05_fd_five_point",

    # # LQ 4x4
    # # PGPE
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_18_48_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_16_var_05",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_21_36_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_16_var_01",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_24_24_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_16_var_005",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_27_14_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_16_var_001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_30_03_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_16_var_0001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_32_52_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_16_var_00005",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_35_40_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_16_var_00001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_38_28_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_16_var_5e-05",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_41_18_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_16_var_1e-05",
    # # PGPE-FD
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-23_36_22_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_05_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-23_38_34_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_01_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-23_40_43_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_005_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-23_42_52_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_001_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-23_45_01_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_0001_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-23_47_11_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_00005_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-23_49_22_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_00001_fd_forward",
    "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-23_51_31_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_5e-05_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-00_09_55_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_01_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-00_23_51_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_005_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-00_37_51_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_001_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-00_51_49_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_0001_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-01_05_45_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_00005_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-01_19_40_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_00001_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-01_33_44_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_5e-05_fd_central",
    "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-01_47_41_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_1e-05_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-02_01_36_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_05_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-02_28_50_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_01_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-02_56_33_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_005_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-03_23_49_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_001_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-03_51_24_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_0001_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-04_18_45_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_00005_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-04_46_06_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_00001_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-05_13_21_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_5e-05_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-05_40_43_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_16_var_1e-05_fd_five_point",

    # #LQ 8x8
    # # PGPE
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_44_06_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_64_var_05",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_47_09_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_64_var_01",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_50_15_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_64_var_005",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_53_16_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_64_var_001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_56_18_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_64_var_0001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-20_59_20_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_64_var_00005",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_02_24_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_64_var_00001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_05_26_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_64_var_5e-05",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_08_28_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_64_var_1e-05",
    # # PGPE-FD
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-06_07_57_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_05_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-06_14_00_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_01_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-06_20_03_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_005_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-06_26_04_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_001_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-06_32_06_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_0001_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-06_38_06_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_00005_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-06_44_05_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_00001_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-06_50_04_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_5e-05_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-06_56_08_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_1e-05_fd_forward",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-07_02_09_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_05_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-07_56_51_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_01_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-08_52_35_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_005_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-09_47_59_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_001_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-10_42_51_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_0001_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-11_38_03_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_00005_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-12_32_31_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_00001_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-13_48_51_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_5e-05_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-14_43_05_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_1e-05_fd_central",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_22-15_37_33_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_05_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_23-10_59_12_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_01_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_23-12_50_33_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_005_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_23-14_42_15_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_001_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_23-16_34_58_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_0001_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_23-18_26_33_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_00005_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_23-20_19_31_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_00001_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_23-22_44_55_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_5e-05_fd_five_point",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_24-00_34_12_seed_0_pgpe_fd_150_lqr_50_adam_01_linear_batch_100_noclip_64_var_1e-05_fd_five_point",

    # LQ 16x16
    # PGPE
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_11_32_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_256_var_05",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_15_15_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_256_var_01",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_18_57_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_256_var_005",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_22_39_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_256_var_001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_26_22_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_256_var_0001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_30_04_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_256_var_00005",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_33_46_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_256_var_00001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_37_29_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_256_var_5e-05",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/test_lqr_multidim/_03_21-21_41_13_seed_0_pgpe_1500_lqr_50_adam_01_linear_batch_100_noclip_256_var_1e-05",

]

# Labels estratte automaticamente (solo lr e var)
def build_label_from_path(path):
    exp_name = os.path.basename(path.rstrip("/")).lstrip("_")
    tokens = exp_name.split("_")

    lr_value = "NA"
    var_value = "NA"
    algo = "NA"

    for i, token in enumerate(tokens[:]):
        if token == "pgpe":
            algo = "PGPE"
        elif token == "fd":
            algo = "PGPE-FD"
        
        if token in ("adam", "constant"):
            lr_type = tokens[i]
            lr_value = tokens[i + 1]
        elif token == "var":
            var_value = tokens[i + 1]

        if token == "forward":
            algo += " og"
        elif token == "central":
            algo += " a"
        elif token == "five":
            algo += " b"

    # return f"{lr_type}={lr_value} | std={var_value}"
    return f"{algo} | std={var_value}"

lab = [build_label_from_path(path) for path in paths]

# Timesteps raccolti a ogni iterazione per ciascun algoritmo
horizon = 50
batch_size = 100
n_params_pgpe_fd = 1

timesteps_per_iteration = horizon * batch_size * (1 + n_params_pgpe_fd) * 2 # PGPE-FD: base + 1 perturbazione per parametro

print(lab)
# Out:
# ['PGPE-FD og | std=5e-05', 'PGPE-FD a | std=1e-05']

# %%
# Plot dei grafici
plt.clf()
# plt.figure(figsize=(6.5, 4.5))
plt.figure(figsize=(10, 6))

def get_timesteps_per_iteration_for_path(path):
    if "_pgpe_fd_" in path:
        if "_fd_five_point" in path:
            fd_multiplier = 4
        elif "_fd_central" in path:
            fd_multiplier = 2
        else:
            fd_multiplier = 1
        return horizon * batch_size * (1 + n_params_pgpe_fd) * fd_multiplier
    return horizon * batch_size

for i, performances in enumerate(all_performances):
    if performances.size > 0:
         # Calcola la media e gli intervalli di confidenza
        mean_performance = np.mean(performances, axis=0)
        std_performance = np.std(performances, axis=0)

        # Asse x in timesteps cumulati
        ts_per_iteration = get_timesteps_per_iteration_for_path(paths[i])
        x = (np.arange(len(mean_performance)) + 1) * ts_per_iteration

        plt.plot(x, mean_performance, linewidth=2, label=lab[i])

        # Plot dell'intervallo di confidenza
        lower = mean_performance-(std_performance)*1.96/np.sqrt(performances.shape[0])
        higher = mean_performance+(std_performance)*1.96/np.sqrt(performances.shape[0])

        plt.fill_between(
            x,
            lower,
            higher,
            alpha=0.2
        )

        # print(np.mean(mean_performance))
        # print(np.mean(lower))
        # print(np.mean(higher))

# for i, performances in enumerate(all_det_performances):
#     if performances.size > 0:
#          # Calcola la media e gli intervalli di confidenza
#         mean_performance = np.mean(performances, axis=0)
#         std_performance = np.std(performances, axis=0)

#         # Asse x in timesteps cumulati
#         x = (np.arange(len(mean_performance)) + 1) * timesteps_per_iteration
        
#         # x = (np.arange(len(mean_performance)))
#         # Plot della curva media
#         plt.plot(x, mean_performance, linewidth=2, label=lab[i] + " (det)")

#         # Plot dell'intervallo di confidenza
#         lower = mean_performance-(std_performance)*1.96/np.sqrt(performances.shape[0])
#         higher = mean_performance+(std_performance)*1.96/np.sqrt(performances.shape[0])

#         plt.fill_between(
#             x,
#             lower,
#             higher,
#             alpha=0.2
#         )

#         # print(np.mean(mean_performance))
#         # print(np.mean(lower))
#         # print(np.mean(higher))

# Etichette e titolo
# plt.title("Dam")
# plt.xlabel("Iterations")
plt.xlabel("Total timesteps")
plt.ylabel("Return")
plt.ylim(bottom=-1000, top=-90)
plt.xlim(0, 2000000)

plt.legend(loc="lower right", ncol=2)
plt.grid()
# plt.ylim(bottom=-400, top=-90)
# plt.xlim(right=0.25*1e7)
# Salva e mostra il grafico
# plt.savefig("swimmer_persistence.pdf", format='pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# # PG Finite Differences

# %%
# # Path principali per i risultati

paths = [
    # LQR 2x2 [2, 32, 32, 2]
    # "/Users/gianmarcotedeschi/Projects/MagicRL/results_lqr_pg_fd_new/deterministic/trajectory/central/linear/_04_24-21_50_30_seed_0_pg_fd_750_lqr_50_adam_001_linear_batch_100_clip_4_var_01",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/results_lqr_pg_fd_new/deterministic/trajectory/central/linear/_04_24-22_12_30_seed_0_pg_fd_750_lqr_50_adam_001_linear_batch_100_clip_4_var_001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/results_lqr_pg_fd_new/deterministic/trajectory/central/linear/_04_24-22_34_23_seed_0_pg_fd_750_lqr_50_adam_001_linear_batch_100_clip_4_var_0001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/results_lqr_pg_fd_new/deterministic/trajectory/central/linear/_04_24-22_56_22_seed_0_pg_fd_750_lqr_50_adam_001_linear_batch_100_clip_4_var_00001",

    # "/Users/gianmarcotedeschi/Projects/MagicRL/results_lqr_pg_fd_new/deterministic/trajectory/central/nn/_04_26-12_29_55_seed_0_pg_fd_750_lqr_50_adam_00001_nn_batch_100_clip_1152_var_01",

    "/Users/gianmarcotedeschi/Projects/MagicRL/results_lqr_pg_fd_new/deterministic/trajectory/forward/linear/_04_24-23_15_53_seed_0_pg_fd_750_lqr_50_adam_0001_linear_batch_100_clip_4_var_01",
    "/Users/gianmarcotedeschi/Projects/MagicRL/results_lqr_pg_fd_new/deterministic/trajectory/forward/linear/_04_24-23_37_47_seed_0_pg_fd_750_lqr_50_adam_0001_linear_batch_100_clip_4_var_001",
    "/Users/gianmarcotedeschi/Projects/MagicRL/results_lqr_pg_fd_new/deterministic/trajectory/forward/linear/_04_24-23_59_44_seed_0_pg_fd_750_lqr_50_adam_0001_linear_batch_100_clip_4_var_0001",
    "/Users/gianmarcotedeschi/Projects/MagicRL/results_lqr_pg_fd_new/deterministic/trajectory/forward/linear/_04_25-00_21_39_seed_0_pg_fd_750_lqr_50_adam_0001_linear_batch_100_clip_4_var_00001",

    # "/Users/gianmarcotedeschi/Projects/MagicRL/results_lqr_pg_fd_new/deterministic/trajectory/forward/nn/_04_26-12_04_59_seed_0_pg_fd_750_lqr_50_adam_00001_nn_batch_100_clip_1152_var_01",

    "/Users/gianmarcotedeschi/Projects/MagicRL/results_lqr_pg_fd_new/stochastic/step/central/linear/_04_24-21_34_29_seed_0_pg_fd_750_lqr_50_adam_001_linear_batch_100_clip_4_var_01",
    "/Users/gianmarcotedeschi/Projects/MagicRL/results_lqr_pg_fd_new/stochastic/trajectory/central/linear/_04_24-21_39_54_seed_0_pg_fd_750_lqr_50_adam_001_linear_batch_100_clip_4_var_01",

    "/Users/gianmarcotedeschi/Projects/MagicRL/results_lqr_pg_fd_new/stochastic/trajectory/forward/linear/_04_24-21_59_08_seed_0_pg_fd_750_lqr_50_adam_001_linear_batch_100_clip_4_var_001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/results_lqr_pg_fd_new/stochastic/trajectory/forward/linear/_04_24-21_59_08_seed_0_pg_fd_750_lqr_50_adam_001_linear_batch_100_clip_4_var_001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/results_lqr_pg_fd_new/stochastic/trajectory/forward/linear/_04_24-22_21_02_seed_0_pg_fd_750_lqr_50_adam_001_linear_batch_100_clip_4_var_0001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/results_lqr_pg_fd_new/stochastic/trajectory/forward/linear/_04_24-22_42_59_seed_0_pg_fd_750_lqr_50_adam_001_linear_batch_100_clip_4_var_00001",

    # "/Users/gianmarcotedeschi/Projects/MagicRL/results_lqr_pg_fd_new/stochastic/step/forward/linear/_04_24-21_30_21_seed_0_pg_fd_750_lqr_50_adam_001_linear_batch_100_clip_4_var_01",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/results_lqr_pg_fd_new/stochastic/step/forward/linear/_04_24-21_53_40_seed_0_pg_fd_750_lqr_50_adam_001_linear_batch_100_clip_4_var_001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/results_lqr_pg_fd_new/stochastic/step/forward/linear/_04_24-22_15_37_seed_0_pg_fd_750_lqr_50_adam_001_linear_batch_100_clip_4_var_0001",
    "/Users/gianmarcotedeschi/Projects/MagicRL/results_lqr_pg_fd_new/stochastic/step/forward/linear/_04_24-22_37_33_seed_0_pg_fd_750_lqr_50_adam_001_linear_batch_100_clip_4_var_00001",
    "/Users/gianmarcotedeschi/Projects/MagicRL/results_old/results_lqr_pg/_04_21-17_23_38_seed_0_pg_1500_lqr_50_adam_001_gaussian_batch_100_noclip_4_var_01"

    # DEBUG!!!!
    # "/Users/gianmarcotedeschi/Projects/MagicRL/results_lqr_pg_fd_new/stochastic/trajectory/central/linear/_04_24-21_39_54_seed_0_pg_fd_750_lqr_50_adam_001_linear_batch_100_clip_4_var_01",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/results_lqr_pg_fd_new/stochastic/trajectory/central/linear/_04_24-22_01_55_seed_0_pg_fd_750_lqr_50_adam_001_linear_batch_100_clip_4_var_001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/results_lqr_pg_fd_new/stochastic/trajectory/central/linear/_04_24-22_23_48_seed_0_pg_fd_750_lqr_50_adam_001_linear_batch_100_clip_4_var_0001",
    # "/Users/gianmarcotedeschi/Projects/MagicRL/results_lqr_pg_fd_new/stochastic/trajectory/central/linear/_04_24-22_45_45_seed_0_pg_fd_750_lqr_50_adam_001_linear_batch_100_clip_4_var_00001",
]

# Labels estratti automaticamente dal path
def build_label_from_path(path):
    clean_path = path.rstrip("/")
    parts = clean_path.split("/")

    # Estratti dalla gerarchia: .../results_lqr_pg_fd_new/<rollout>/<scope>/<fd_mode>/<policy>/<exp_name>
    rollout_mode = parts[-5] if len(parts) >= 5 else "NA"
    perturb_scope = parts[-4] if len(parts) >= 4 else "NA"
    fd_mode = parts[-3] if len(parts) >= 3 else "NA"
    policy = parts[-2] if len(parts) >= 2 else "NA"

    # fallback dal nome esperimento se necessario
    exp_name = os.path.basename(clean_path).lstrip("_")
    tokens = exp_name.split("_")

    if policy == "NA":
        if "linear" in tokens:
            policy = "linear"
        elif "nn" in tokens:
            policy = "nn"

    if fd_mode == "NA":
        if "forward" in tokens:
            fd_mode = "forward"
        elif "central" in tokens:
            fd_mode = "central"
        elif "five" in tokens or "five_point" in tokens:
            fd_mode = "five_point"

    if rollout_mode == "NA":
        if "deterministic" in tokens:
            rollout_mode = "deterministic"
        elif "stochastic" in tokens:
            rollout_mode = "stochastic"

    if perturb_scope == "NA":
        if "trajectory" in tokens:
            perturb_scope = "trajectory"
        elif "step" in tokens:
            perturb_scope = "step"

    return f"{rollout_mode} | {policy} | {fd_mode} | {perturb_scope}"

lab = [build_label_from_path(path) for path in paths]

# Timesteps raccolti a ogni iterazione per ciascun algoritmo
horizon = 50
batch_size = 100

print(lab)
# Out:
# ['stochastic | linear | central | trajectory', 'stochastic | linear | central | trajectory', 'stochastic | linear | central | trajectory', 'stochastic | linear | central | trajectory']

# %%
# Lista per memorizzare le performance per ogni set
all_performances = []
all_det_performances = []

for path in paths:
    performances, det_performances = load_trials(path, n_exp=3)
    if performances.size > 0:
        all_performances.append(performances)
    if det_performances.size > 0:
        all_det_performances.append(det_performances)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Plot dei grafici
plt.clf()
plt.figure(figsize=(10, 6))

def get_timesteps_per_iteration_for_path(path):
    clean_path = path.rstrip("/")
    parts = clean_path.split("/")

    rollout_mode = parts[-5] if len(parts) >= 5 else "NA"
    fd_mode_local = parts[-3] if len(parts) >= 3 else "NA"

    if fd_mode_local == "NA":
        if "_fd_five_point" in clean_path:
            fd_mode_local = "five_point"
        elif "_fd_central" in clean_path:
            fd_mode_local = "central"
        else:
            fd_mode_local = "forward"

    if rollout_mode == "deterministic":
        dim_action = 2
        if fd_mode_local == "forward":
            rollout_multiplier = 1 + dim_action
        elif fd_mode_local == "central":
            rollout_multiplier = 1 + 2 * dim_action
        elif fd_mode_local == "five_point":
            rollout_multiplier = 1 + 4 * dim_action
        else:
            rollout_multiplier = 1 + dim_action
    else:
        if fd_mode_local == "forward":
            rollout_multiplier = 2
        elif fd_mode_local == "central":
            rollout_multiplier = 3
        elif fd_mode_local == "five_point":
            rollout_multiplier = 5
        else:
            rollout_multiplier = 2

    return (horizon * batch_size) * rollout_multiplier

# NEW: Initialize a list to keep track of the final x-value for each curve
max_x_values = []

for i, performances in enumerate(all_performances):
    if performances.size > 0:
        mean_performance = np.mean(performances, axis=0)
        std_performance = np.std(performances, axis=0)

        ts_per_iteration = get_timesteps_per_iteration_for_path(paths[i])
        x = (np.arange(len(mean_performance)) + 1) * ts_per_iteration

        # NEW: Store the last x-coordinate (the total timesteps for this specific run)
        if len(x) > 0:
            max_x_values.append(x[-1])

        if i == max(0, len(all_performances) - 1):  # Highlight the second to last curve
            plt.plot(x, mean_performance, linewidth=2, label="PG")
        else:
            plt.plot(x, mean_performance, linewidth=2, label=lab[i])

        lower = mean_performance - (std_performance) * 1.96 / np.sqrt(performances.shape[0])
        higher = mean_performance + (std_performance) * 1.96 / np.sqrt(performances.shape[0])

        plt.fill_between(
            x,
            lower,
            higher,
            alpha=0.2
        )


plt.xlabel("Total timesteps")
plt.ylabel("Return")

plt.legend(loc="lower right", ncol=2)
plt.grid()
plt.ylim(bottom=-400, top=-90)

# NEW: Enforce the x-axis to stop at the minimum of the maximum x-values we collected
# if max_x_values:
#     minimum_total_timesteps = min(max_x_values)
#     plt.xlim(right=minimum_total_timesteps)

plt.show()

# %%
import numpy as np
import matplotlib
if not hasattr(matplotlib.rcParams, '_get'):
    matplotlib.rcParams._get = matplotlib.rcParams.get
import matplotlib.pyplot as plt
import os
import json

def local_load_trials(base_path, n_exp=3):
    trial_performances = []
    det_performances = []
    for i in range(n_exp):
        trial_path = os.path.join(base_path, f"_trial_{i}")
        if os.path.isdir(trial_path):
            try:
                file_path = os.path.join(trial_path, "results.json")
                with open(file_path, 'r') as file:
                    data = json.load(file)
                    trial_performances.append(data["performance"])
            except (FileNotFoundError, json.JSONDecodeError) as e:
                print(f"Error reading {file_path}: {e}")
    return np.array(trial_performances)

def build_label_from_path(path):
    clean_path = path.rstrip("/")
    exp_name = os.path.basename(clean_path).lstrip("_")
    tokens = exp_name.split("_")
    
    algo = "PG"
    if "pg" in tokens and "fd" in tokens:
        algo = "PG-FD"
        
        # Try to infer scopes if it's FD
        parts = clean_path.split("/")
        fd_mode = parts[-3] if len(parts) >= 3 else "NA"
        perturb_scope = parts[-4] if len(parts) >= 4 else "NA"
        
        if fd_mode != "NA" and perturb_scope != "NA":
            algo += f" ({fd_mode} {perturb_scope})"
            
    # Find LR and Var
    lr_value = "NA"
    var_value = "NA"
    
    for i, token in enumerate(tokens):
        if token in ("adam", "constant"):
            if i + 1 < len(tokens):
                # Check for zero-prefixed decimals e.g., '01' -> '0.1', '001' -> '0.01'
                lr_str = tokens[i+1]
                if lr_str.startswith("0") and len(lr_str) >= 2:
                    lr_value = "0." + lr_str[1:]
                else:
                    lr_value = lr_str
        elif token == "var":
            if i + 1 < len(tokens):
                var_str = tokens[i+1]
                if var_str.startswith("0") and len(var_str) >= 2:
                    var_value = "0." + var_str[1:]
                else:
                    var_value = var_str

    label = f"{algo} | LR {lr_value} | Var {var_value}"
    return label

paths = [
    "/home/fis4/MagicRL/results_mujoco_pg/swimmer/_04_27-21_40_50_seed_0_pg_500_swimmer_200_adam_01_gaussian_batch_100_noclip_16_var_01",
    "/home/fis4/MagicRL/results_mujoco_pg/swimmer/_04_27-21_46_12_seed_0_pg_500_swimmer_200_adam_001_gaussian_batch_100_noclip_16_var_01"
]

labels = [build_label_from_path(p) for p in paths]

plt.figure(figsize=(10, 6))

for idx, path in enumerate(paths):
    perfs = local_load_trials(path)
    if perfs.size > 0:
        mean_perf = np.mean(perfs, axis=0)
        std_perf = np.std(perfs, axis=0)
        
        ts_per_iteration = get_timesteps_per_iteration_for_path(paths[i])
        x = (np.arange(len(mean_performance)) + 1) * ts_per_iteration
        
        # x = np.arange(len(mean_perf))
        
        plt.plot(x, mean_perf, linewidth=2, label=labels[idx])
        plt.fill_between(
            x,
            mean_perf - std_perf * 1.96 / np.sqrt(perfs.shape[0]),
            mean_perf + std_perf * 1.96 / np.sqrt(perfs.shape[0]),
            alpha=0.2
        )

plt.xlabel("Iterations")
plt.ylabel("Return")
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib
if not hasattr(matplotlib.rcParams, '_get'):
    matplotlib.rcParams._get = matplotlib.rcParams.get
import matplotlib.pyplot as plt
import os
import json
import glob
import matplotlib.cm as cm

def local_load_trials(base_path, n_exp=3, key="performance"):
    trial_performances = []
    for i in range(n_exp):
        trial_path = os.path.join(base_path, f"_trial_{i}")
        if os.path.isdir(trial_path):
            try:
                file_path = os.path.join(trial_path, "results.json")
                with open(file_path, 'r') as file:
                    data = json.load(file)
                    trial_performances.append(data[key])
            except (FileNotFoundError, json.JSONDecodeError, KeyError) as e:
                print(f"Error reading {file_path}: {e}")
    return np.array(trial_performances)

def get_timesteps_per_iteration_for_path(path, dim_action):
    # Default values
    clean_path = path.rstrip("/")
    parts = clean_path.split("/")

    rollout_mode = parts[-5] if len(parts) >= 5 else "NA"
    fd_mode_local = parts[-3] if len(parts) >= 3 else "NA"

    exp_name = parts[-1]
    tokens = exp_name.split("_")

    # Dynamically extract batch_size and horizon from the experiment name
    # Common environment name tokens that precede the horizon length:
    env_tokens = {"cheetah", "hopper", "swimmer", "ip", "lqr", "ant", "cartpole", "humanoid", "reacher"}
    
    for i, token in enumerate(tokens):
        if token == "batch" and i + 1 < len(tokens):
            try:
                batch_size = int(tokens[i+1])
            except ValueError:
                pass
        elif token in env_tokens and i + 1 < len(tokens):
            try:
                horizon = int(tokens[i+1])
            except ValueError:
                pass

    # swimmer 2
    # hopper 3
    # half cheetah 6
    # lq 2x2 2

    if rollout_mode == "deterministic":
        if fd_mode_local == "forward":
            rollout_multiplier = 1 + dim_action
        elif fd_mode_local == "central":
            rollout_multiplier = 1 + 2 * dim_action
    
    elif rollout_mode == "stochastic":
        if fd_mode_local == "forward":
            rollout_multiplier = 2
        elif fd_mode_local == "central":
            rollout_multiplier = 2
    else:
        rollout_multiplier = 1

    return (horizon * batch_size) * rollout_multiplier

def build_label_from_path(path):
    clean_path = path.rstrip("/")
    parts = clean_path.split("/")
    exp_name = parts[-1]
    tokens = exp_name.split("_")
    
    # Safely extract directory structures if they exist
    rollout_mode = "NA"
    perturb_scope = "NA"
    fd_mode = "NA"
    policy = "NA"
    
    if len(parts) >= 6:
        policy = parts[-2]
        fd_mode = parts[-3]
        perturb_scope = parts[-4]
        rollout_mode = parts[-5]

    algo = "PG"
    if "pg" in tokens and "fd" in tokens:
        algo = "PG-FD"
        if fd_mode != "NA" and perturb_scope != "NA" and rollout_mode != "NA":
            algo += f" ({rollout_mode} | {perturb_scope} | {fd_mode})"

    # Find LR and Var inside the exp_name tokens
    lr_value = "NA"
    var_value = "NA"
    
    for i, token in enumerate(tokens):
        if token in ("adam", "constant"):
            if i + 1 < len(tokens):
                lr_str = tokens[i+1]
                lr_value = f"0.{lr_str[1:]}" if lr_str.startswith("0") and len(lr_str) > 1 else lr_str
        elif token == "var":
            if i + 1 < len(tokens):
                var_str = tokens[i+1]
                var_value = f"0.{var_str[1:]}" if var_str.startswith("0") and len(var_str) > 1 else var_str

    label = f"{algo} | Pol: {policy} | LR: {lr_value} | Var: {var_value}"
    
    metadata = {
        "algo": algo,
        "policy": policy,
        "rollout_mode": rollout_mode,
        "perturb_scope": perturb_scope,
        "fd_mode": fd_mode,
        "lr_value": lr_value,
        "var_value": var_value
    }
    
    return label, metadata

# %%
# ====================================================
# FILTERS
# Set to 'None' to keep all, or a specific string to filter.
# e.g., FILTER_POLICY = "linear" or FILTER_ROLLOUT_MODE = "deterministic"
# ====================================================
FILTER_POLICY = "linear"
FILTER_ROLLOUT_MODE = "stochastic"
FILTER_PERTURB_SCOPE = None
FILTER_FD_MODE = "central"
FILTER_LR = None
FILTER_VAR = "0.1"
# ====================================================


# root_dir = "/home/fis4/MagicRL/ip_4/ip"
# root_dir = "/home/fis4/MagicRL/swimmer_new/swimmer"
# root_dir = "/home/fis4/MagicRL/hopper_new/hopper"
# root_dir = "/home/fis4/MagicRL/result_lqr_new/lqr_2"
# root_dir = "/home/fis4/MagicRL/ip_test/ip"
# root_dir = "/home/fis4/MagicRL/swimmer_new_2/swimmer"
root_dir = "/home/fis4/MagicRL/ip_new/ip"

# Dynamically find all experiment directories containing a '_trial_0' folder
all_paths = []
for root, dirs, files in os.walk(root_dir):
    if "_trial_0" in dirs:
        all_paths.append(root)

# Sort them alphabetically for consistency
all_paths = sorted(all_paths)

# Apply filters
paths = []
labels = []

for p in all_paths:
    lbl, meta = build_label_from_path(p)
    
    # Always include PG experiments; test filters only for other algos
    if meta.get("algo") != "PG":
        if FILTER_POLICY is not None and meta["policy"] != FILTER_POLICY:
            continue
        if FILTER_ROLLOUT_MODE is not None and meta["rollout_mode"] != FILTER_ROLLOUT_MODE:
            continue
        if FILTER_PERTURB_SCOPE is not None and meta["perturb_scope"] != FILTER_PERTURB_SCOPE:
            continue
        if FILTER_FD_MODE is not None and meta["fd_mode"] != FILTER_FD_MODE:
            continue
        if FILTER_LR is not None and meta["lr_value"] != FILTER_LR:
            continue
        if FILTER_VAR is not None and meta["var_value"] != FILTER_VAR:
            continue
        
    paths.append(p)
    labels.append(lbl)

# Plotting block
if len(paths) == 0:
    print("No experiments matched the specified filters!")
else:
    plt.figure(figsize=(14, 8))

    # Generate a distinct color array using exactly as many colors as there are paths
    colors = cm.rainbow(np.linspace(0, 1, max(1, len(paths))))

    for idx, path in enumerate(paths):
        _, meta = build_label_from_path(path)
        perf_key = "deterministic_res" if meta.get("algo") == "PG" else "performance"
        perfs = local_load_trials(path, key=perf_key)
        
        if perfs.size > 0:
            mean_perf = np.mean(perfs, axis=0)
            std_perf = np.std(perfs, axis=0)
            
            if "half_cheetah" in path:
                dim_action = 6
            elif "hopper" in path:
                dim_action = 3
            elif "swimmer" in path:
                dim_action = 2
            elif "lqr" in path:
                dim_action = 2  
            elif "ip" in path:
                dim_action = 1

            ts_per_iteration = get_timesteps_per_iteration_for_path(path, dim_action)
            x = (np.arange(len(mean_perf)) + 1) * ts_per_iteration

            line, = plt.plot(x, mean_perf, linewidth=2, label=labels[idx], color=colors[idx])
            plt.fill_between(
                x,
                mean_perf - std_perf * 1.96 / np.sqrt(perfs.shape[0]),
                mean_perf + std_perf * 1.96 / np.sqrt(perfs.shape[0]),
                alpha=0.15,
                color=colors[idx]
            )

    plt.xlabel("Timesteps")
    plt.ylabel("Return")
    # plt.ylim(bottom=-600, top=-90)
    # plt.xlim(left=0, right=1e6)
    plt.legend(loc='center left', bbox_to_anchor=(1.02, 0.5), fontsize='small')
    plt.grid(True)
    # Adjust subplot to explicitly make room for the legend on the right
    # instead of using tight_layout which can completely squish the plot
    plt.subplots_adjust(right=0.7)
    plt.show()
